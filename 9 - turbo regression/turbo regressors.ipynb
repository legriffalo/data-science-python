# %%
# requires internet connection!
exec('''import urllib; exec(urllib.request.urlopen('https://raw.githubusercontent.com/NickGMV/visual-tools/main/visual-aids-jupyter8.txt').read())''')
# Out:
# settings found initialising with personal preferences...
# ['126%', '125%', '#a2dde2', '#f9f9a9', '127%', '#f9f995', '#b521c0', '126%']
# <script>
# var profile = ['126%', '125%', '#a2dde2', '#f9f9a9', '127%', '#f9f995', '#b521c0', '126%']
# </script>
# <script>
# var box1 = document.getElementById('help_box');
# var box2 = document.getElementById('settings');
# var logo = document.getElementById('mvlogo');
# var tt = document.getElementById('tooltip2');
# if(box1){
# //clean out for rebuild
# box1.remove();
# box2.remove();
# logo.remove();
# tt.remove();
# clearInterval(flagEnlarge);
# clearInterval(flagMagnifyOutputs);
# clearInterval(flagHighlightOutput);
# clearInterval(flagHighlight);
# clearInterval(flagHighlightCode);
# clearInterval(flagMagnifyCell);
# clearInterval(flagMagnifyCode);
# }
# else{}
#
#
# var flagHighlight=0;
# var flagHighlightCode = 0;
# var flagMagnifyCell = 0;
# var flagMagnifyCode =0;
# var flagMagnifyOutputs=0;
# var flagEnlarge = 0;
# ...

# %%
# building the turbo regressor


# function to import all libraries
# basic libraries
from itertools import chain,combinations
# simple pandas and plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# train test splits 
from sklearn.model_selection import train_test_split

# encoding categoricals
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# import regression models
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# import metrics libraries

# %%
data = pd.read_csv('./insurance.csv')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# column permutations
def powerset(iterable):
    s = list(iterable)
    x = list(chain.from_iterable(combinations(s, r) for r in range(len(s)+1)))[1:]
    return [list(i) for i in x]

combos = powerset(data.columns)

# %%
# column encoder
def encoder(data,independant):
    l = [c for c in data.columns if c!=independant]
    print(l)
    for column in l:
        if data[column].dtype in ['object']:
            print('yo')
            print(data[column].dtype)
            data = pd.get_dummies(data,columns = [column],drop_first = True)
            
    return data

# %%
def build_regressions(combinations,dependant):
    #build standard lr

# %%
#encoder(data,'charges')
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region']
# yo
# object
# yo
# object
# yo
# object
#       age     bmi  children      charges  sex_male  smoker_yes  \
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object
